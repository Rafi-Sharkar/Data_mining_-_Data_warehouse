# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
import plotly.express as px

# %%
# Q2
df = pd.read_csv("/content/drive/MyDrive/data set/wheetseeds.csv")

# %%
# Q3
# take spacific column
x = df.loc[:,["Area","Perimeter","Compactness","Class"]]
y = x.to_numpy()
print(y)

# %%
# Q4
# Separate data by class
class1 = x.loc[x.Class == 1,["Area","Perimeter","Compactness"]].to_numpy()
class2 = x.loc[x.Class == 2,["Area","Perimeter","Compactness"]].to_numpy()
class3 = x.loc[x.Class == 3,["Area","Perimeter","Compactness"]].to_numpy()

# Create a 3D plot
fig = plt.figure(figsize = (12,8))
ax = fig.add_subplot(projection='3d')

# Plot data points with different shapes
ax.scatter(*zip(*class1), marker='o', label='Class 1 (Circle)')
ax.scatter(*zip(*class2), marker='s', label='Class 2 (Square)')
ax.scatter(*zip(*class3), marker='^', label='Class 3 (Triangle)')

# Set labels for each axis
ax.set_xlabel('Area')
ax.set_ylabel('Perimeter')
ax.set_zlabel('Compactness')

ax.legend()
plt.show()

# %%
# Q5
# Separate data by class
class1 = x.loc[x.Class == 1,["Area","Perimeter","Compactness"]].to_numpy()
class2 = x.loc[x.Class == 2,["Area","Perimeter","Compactness"]].to_numpy()
class3 = x.loc[x.Class == 3,["Area","Perimeter","Compactness"]].to_numpy()

class1_mean = np.mean(class1, axis=0)
class2_mean = np.mean(class2, axis=0)
class3_mean = np.mean(class3, axis=0)

print(class1_mean)
print(class2_mean)
print(class3_mean)


# # Create a 3D plot
fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot(projection='3d')

# Plot data points with different shapes
ax.scatter(class1[:, 0], class1[:, 1], class1[:, 2], marker='o', label='Class 1', color="r")
ax.scatter(class2[:, 0], class2[:, 1], class2[:, 2], marker='s', label='Class 1', color="b")
ax.scatter(class3[:, 0], class3[:, 1], class3[:, 2], marker='^', label='Class 1', color="g")

# mean
ax.scatter(class1_mean[0], class1_mean[1], class1_mean[2], s=100, marker='o', color='black')
ax.scatter(class2_mean[0], class2_mean[1], class2_mean[2], s=100, marker='s', color='black')
ax.scatter(class3_mean[0], class3_mean[1], class3_mean[2], s=100, marker='^', color='black')

# Set labels for each axis
ax.set_xlabel('Area')
ax.set_ylabel('Perimeter')
ax.set_zlabel('Compactness')

ax.legend()
plt.show()
# Out:
# [14.33442857 14.29428571  0.88007   ]
# [18.33428571 16.13571429  0.88351714]
# [11.87385714 13.24785714  0.84940857]

# %%
#Q6
Area = y[:,:1]
plt.title("Area", fontsize=20)
l = [5, 10, 15, 20, 25]
plt.hist(Area, bins=l, color="g", edgecolor = "black")
plt.show()

# %%
#Q6
Perimeter= y[:,1:2]
plt.title("Perimeter", fontsize = 20)
plt.hist(Perimeter, bins = [5, 10, 15, 20], color="m", edgecolor = "black")
plt.show()

# %%
#Q7
Area=y[:,:1]
Perimeter=y[:,1:2]

print("Standard deviation of Area is ",np.std(Area))
print("Standard deviation of perimeter is ",np.std(Perimeter))
# Out:
# Standard deviation of area is  2.902763307757227
# Standard deviation of perimeter is  1.3028455904876302

# %%
#Q8
Area = y[:, :1]
plt.boxplot(Area, vert=False, labels=["Area"])
plt.show()

# %%
#Q8
Perimeter = y[:, 1:2]
plt.boxplot(Perimeter, vert=False, labels=["Perimeter"])
plt.show()

# %%
#Q9
# Separate data by class
class1_area = x.loc[x.Class == 1,["Area"]].to_numpy().flatten()
class2_area = x.loc[x.Class == 2,["Area"]].to_numpy().flatten()
class3_area = x.loc[x.Class == 3,["Area"]].to_numpy().flatten()

# marge all area in list
All_Area = [class1_area, class2_area, class3_area]

# plot them
plt.title("Area",fontsize = 15)
plt.boxplot(All_Area, labels = ["Class_1_Area","Class_2_Area","Class_3_Area"])
plt.show()

# %%
#Q9
# Separate data by class
class1_perimeter = x.loc[x.Class == 1,["Perimeter"]].to_numpy().flatten()
class2_perimeter = x.loc[x.Class == 2,["Perimeter"]].to_numpy().flatten()
class3_perimeter = x.loc[x.Class == 3,["Perimeter"]].to_numpy().flatten()

# marge all area in list
All_Perimeter = [class1_perimeter, class2_perimeter, class3_perimeter]

# plot them
plt.title("Perimeter",fontsize = 15)
plt.boxplot(All_Perimeter, labels = ["Class_1_Perimeter","Class_2_Perimeter","Class_3_Perimeter"])
plt.show()

# %%
#Q10
x = df.loc[:,["Area","Perimeter","Compactness","Length of kernel", "width of kernel",	"Asymmetry coefficient", "Length of kernel groove", "Class"]]
matplt=["Area","Perimeter"]
pd.plotting.scatter_matrix(x[matplt])

plt.show()

# %%
#Q11
para=["Area","Perimeter"]
px.parallel_coordinates(data_frame=x[para])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eeda1ce1-4f0d-4a91-a636-2d33e8f34ed1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eeda1ce1-4f0d-4a91-a636-2d33e8f34ed1")) {                    Plotly.newPlot(                        "eeda1ce1-4f0d-4a91-a636-2d33e8f34ed1",                        [{"dimensions":[{"label":"Area","values":[15.26,14.88,14.29,13.84,16.14,14.38,14.69,14.11,16.63,16.44,15.26,14.03,13.89,13.78,13.74,14.59,13.99,15.69,14.7,12.72,14.16,14.11,15.88,12.08,15.01,16.19,13.02,12.74,14.11,13.45,13.16,15.49,14.09,13.94,15.05,16.12,16.2,17.08,14.8,14.28,13.54,13.5,13.16,15.5,15.11,13.8,15.36,14.99,14.79,14.86,14.43,15.78,14.49,14.33,14.52,15.03,14.46,14.92,15.38,12.11,11.42,11.23,12.36,13.22,12.78,12.88,14.34,14.01,14.37,12.73,17.63,16.84,17.26,19.11,16.82,16.77,17.32,20.71,18.94,17.12,16.53,18.72,20.2,19.57,19.51,18.27,18.88,18.98,21.18,20.88,20.1,18.76,18.81,18.59,18.36,16.87,19.31,18.98,18.17,18.72,16.41,17.99,19.46,19.18,18.95,18.83,18.85,17.63,19.94,18.55,18.45,19.38,19.13,19.14,20.97,19.06,18.96,19.15,18.89,20.03,20.24,18.14,16.17,18.43,15.99,18.75,18.65,17.98,20.16,17.55,18.3,18.94,15.38,16.16,15.56,15.38,17.36,15.57,15.6,16.23,13.07,13.32,13.34,12.22,11.82,11.21,11.43,12.49,12.7,10.79,11.83,12.01,12.26,11.18,11.36,11.19,11.34,12.13,11.75,11.49,12.54,12.02,12.05,12.55,11.14,12.1,12.44,12.15,11.35,11.24,11.02,11.55,11.27,11.4,10.83,10.8,11.26,10.74,11.48,12.21,11.41,12.46,12.19,11.65,12.89,11.56,11.81,10.91,11.23,10.59,10.93,11.27,11.87,10.82,12.11,12.8,12.79,13.37,12.62,12.76,12.38,12.67,11.18,12.7,12.37,12.19,11.23,13.2,11.84,12.3]},{"label":"Perimeter","values":[14.84,14.57,14.09,13.94,14.99,14.21,14.49,14.1,15.46,15.25,14.85,14.16,14.02,14.06,14.05,14.28,13.83,14.75,14.21,13.57,14.4,14.26,14.9,13.23,14.76,15.16,13.76,13.67,14.18,14.02,13.82,14.94,14.41,14.17,14.68,15.0,15.27,15.38,14.52,14.17,13.85,13.85,13.55,14.86,14.54,14.04,14.76,14.56,14.52,14.67,14.4,14.91,14.61,14.28,14.6,14.77,14.35,14.43,14.77,13.47,12.86,12.63,13.19,13.84,13.57,13.5,14.37,14.29,14.39,13.75,15.98,15.67,15.73,16.26,15.51,15.62,15.91,17.23,16.49,15.55,15.34,16.19,16.89,16.74,16.71,16.09,16.26,16.66,17.21,17.05,16.99,16.2,16.29,16.05,16.52,15.65,16.59,16.57,16.26,16.34,15.25,15.86,16.5,16.63,16.42,16.29,16.17,15.86,16.92,16.22,16.12,16.72,16.31,16.61,17.25,16.45,16.2,16.45,16.23,16.9,16.91,16.12,15.38,15.97,14.89,16.18,16.41,15.85,17.03,15.66,15.89,16.32,14.9,15.33,14.89,14.66,15.76,15.15,15.11,15.18,13.92,13.94,13.95,13.32,13.4,13.13,13.13,13.46,13.71,12.93,13.23,13.52,13.6,13.04,13.05,13.05,12.87,13.73,13.52,13.22,13.67,13.33,13.41,13.57,12.79,13.15,13.59,13.45,13.12,13.0,13.0,13.1,12.97,13.08,12.96,12.57,13.01,12.73,13.05,13.47,12.95,13.41,13.36,13.07,13.77,13.31,13.45,12.8,12.82,12.41,12.8,12.86,13.02,12.83,13.27,13.47,13.53,13.78,13.67,13.38,13.44,13.32,12.72,13.41,13.47,13.2,12.88,13.66,13.21,13.34]}],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"name":"","type":"parcoords"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[ ...
